# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.8.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.4
# attrs                     25.1.0
# babel                     2.16.0
# beautifulsoup4            4.12.3
# bleach                    6.2.0
# certifi                   2025.1.31
# cffi                      1.17.1
# charset-normalizer        3.4.1
# colorama                  0.4.6
# comm                      0.2.2
# contourpy                 1.3.1
# cycler                    0.12.1
# debugpy                   1.8.12
# decorator                 5.1.1
# defusedxml                0.7.1
# executing                 2.2.0
# fastjsonschema            2.21.1
# fonttools                 4.55.8
# fqdn                      1.5.1
# h11                       0.14.0
# httpcore                  1.0.7
# ...

# %%
#import library
import pandas as pd
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.info
# Out:
# <bound method DataFrame.info of Empty DataFrame
# Columns: []
# Index: []>

# %%
city = ['dhaka', 'comilla', 'chandpur']
city
# Out:
# ['dhaka', 'comilla', 'chandpur']

# %%
df = pd.DataFrame (city)
df
# Out:
#           0
# 0     dhaka
# 1   comilla
# 2  chandpur

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (3, 1)

# %%
df = pd.DataFrame(city, columns=['District'], index=['number 1','number 2','number 3'])
df
# Out:
#           District
# number 1     dhaka
# number 2   comilla
# number 3  chandpur

# %%
city2 = ['Khulna','Barishal', 'Rangopur']
df2 = pd.DataFrame(zip(city,city2), columns=['district1','district2'])
df2
# Out:
#   district1 district2
# 0     dhaka    Khulna
# 1   comilla  Barishal
# 2  chandpur  Rangopur

# %%
df2.shape
# Out:
# (3, 2)

# %%
df2.index[0:1]
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
df2.index[1]
# Out:
# 1

# %%
import numpy as np
city3 = np.array([['bagura', 'vhola', 'Rajshahi'],['bagerhat','dinajpur','Satkhira']])
city3
# Out:
# array([['bagura', 'vhola', 'Rajshahi'],
#        ['bagerhat', 'dinajpur', 'Satkhira']], dtype='<U8')

# %%
df3 = pd.DataFrame(zip(city,city2,city3), columns=['district1','district2','district3'])
df3
# Out:
#   district1 district2                       district3
# 0     dhaka    Khulna       [bagura, vhola, Rajshahi]
# 1   comilla  Barishal  [bagerhat, dinajpur, Satkhira]

# %%
type(city3)
# Out:
# numpy.ndarray

# %%
df = pd.read_csv("Screentime-App-Details-Dataset.csv")
df.head()
# Out:
#          Date  Usage  Notifications  Times opened        App
# 0  08/26/2022     38             70            49  Instagram
# 1  08/27/2022     39             43            48  Instagram
# 2  08/28/2022     64            231            55  Instagram
# 3  08/29/2022     14             35            23  Instagram
# 4  08/30/2022      3             19             5  Instagram

# %%
df.tail()
# Out:
#           Date  Usage  Notifications  Times opened       App
# 49  09/17/2022    212            212           120  Whatsapp
# 50  09/18/2022    244            303           132  Whatsapp
# 51  09/19/2022     77            169           105  Whatsapp
# 52  09/20/2022     58            190            78  Whatsapp
# 53  09/21/2022     89            262            68  Whatsapp

# %%
df.shape
# Out:
# (54, 5)

# %%
df.head(3)
# Out:
#          Date  Usage  Notifications  Times opened        App
# 0  08/26/2022     38             70            49  Instagram
# 1  08/27/2022     39             43            48  Instagram
# 2  08/28/2022     64            231            55  Instagram

# %%
df.Notifications
# Out:
# 0      70
# 1      43
# 2     231
# 3      35
# 4      19
# 5      25
# 6      23
# 7      28
# 8      15
# 9      29
# 10     24
# 11     34
# 12     23
# 13     48
# 14     68
# 15     71
# 16    180
# 17     99
# 18     45
# 19     10
# 20     15
# 21     13
# 22      9
# 23      8
# 24      8
# 25     11
# 26     12
# 27    209
# 28    111
# 29    183
# 30    157
# 31    246
# 32    169
# 33     99
# 34    144
# 35     80
# 36     38
# 37    218
# 38    205
# 39    212
# 40    217
# 41    405
# 42    166
# 43    173
# 44    290
# 45    153
# 46    192
# 47    181
# 48    176
# 49    212
# 50    303
# 51    169
# 52    190
# 53    262
# Name: Notifications, dtype: int64

# %%
df[['Times opened']]
# Out:
#     Times opened
# 0             49
# 1             48
# 2             55
# 3             23
# 4              5
# 5             20
# 6             57
# 7             22
# 8             25
# 9             30
# 10            51
# 11            25
# 12            19
# 13            43
# 14            70
# 15            70
# 16            95
# 17           102
# 18            39
# 19             2
# 20             4
# 21             5
# 22             3
# 23             5
# 24             3
# 25             5
# 26             8
# 27           105
# 28            68
# 29            86
# 30            74
# 31            87
# 32            77
# 33            47
# 34           103
# 35            16
# 36            33
# 37           121
# 38           110
# 39            83
# 40            82
# 41           192
# 42            79
# 43            92
# 44           172
# 45            91
# 46            67
# 47            58
# 48            91
# 49           120
# 50           132
# ...

# %%
df['Date'].head()
# Out:
# 0    08/26/2022
# 1    08/27/2022
# 2    08/28/2022
# 3    08/29/2022
# 4    08/30/2022
# Name: Date, dtype: object

# %%
df[['App','Date']].head()
# Out:
#          App        Date
# 0  Instagram  08/26/2022
# 1  Instagram  08/27/2022
# 2  Instagram  08/28/2022
# 3  Instagram  08/29/2022
# 4  Instagram  08/30/2022

# %%
df.sort_values('App', ascending=False)
# Out:
#           Date  Usage  Notifications  Times opened        App
# 27  08/26/2022     82            209           105   Whatsapp
# 28  08/27/2022     69            111            68   Whatsapp
# 30  08/29/2022     59            157            74   Whatsapp
# 31  08/30/2022    128            246            87   Whatsapp
# 32  08/31/2022    108            169            77   Whatsapp
# 33  09/01/2022     23             99            47   Whatsapp
# 34  09/02/2022     76            144           103   Whatsapp
# 35  09/03/2022      1             80            16   Whatsapp
# 36  09/04/2022      6             38            33   Whatsapp
# 37  09/05/2022    126            218           121   Whatsapp
# 38  09/06/2022     91            205           110   Whatsapp
# 39  09/07/2022    160            212            83   Whatsapp
# 40  09/08/2022     69            217            82   Whatsapp
# 41  09/09/2022    119            405           192   Whatsapp
# ...

# %%
df.sort_values('App', ascending=True)
# Out:
#           Date  Usage  Notifications  Times opened        App
# 0   08/26/2022     38             70            49  Instagram
# 25  09/20/2022      5             11             5  Instagram
# 24  09/19/2022      4              8             3  Instagram
# 23  09/18/2022      3              8             5  Instagram
# 22  09/17/2022      2              9             3  Instagram
# 21  09/16/2022      3             13             5  Instagram
# 20  09/15/2022      2             15             4  Instagram
# 19  09/14/2022      1             10             2  Instagram
# 18  09/13/2022     17             45            39  Instagram
# 17  09/12/2022    114             99           102  Instagram
# 16  09/11/2022     94            180            95  Instagram
# 15  09/10/2022     45             71            70  Instagram
# 14  09/09/2022     43             68            70  Instagram
# 26  09/21/2022      2             12             8  Instagram
# ...

# %%
#Statistical Analysis
df.describe()
# Out:
#             Usage  Notifications  Times opened
# count   54.000000      54.000000     54.000000
# mean    65.037037     117.703704     61.481481
# std     58.317272      97.017530     43.836635
# min      1.000000       8.000000      2.000000
# 25%     17.500000      25.750000     23.500000
# 50%     58.500000      99.000000     62.500000
# 75%     90.500000     188.250000     90.000000
# max    244.000000     405.000000    192.000000

# %%
# #Correlation. but in this case not run the program
# df.corr()

# %%
# import seaborn as sns
# sns.heatmap(df.corr(), annot=True)

# %%
#Subsecting rows
df[df['App'] == 'Whatsapp' ]
# Out:
#           Date  Usage  Notifications  Times opened       App
# 27  08/26/2022     82            209           105  Whatsapp
# 28  08/27/2022     69            111            68  Whatsapp
# 29  08/28/2022    130            183            86  Whatsapp
# 30  08/29/2022     59            157            74  Whatsapp
# 31  08/30/2022    128            246            87  Whatsapp
# 32  08/31/2022    108            169            77  Whatsapp
# 33  09/01/2022     23             99            47  Whatsapp
# 34  09/02/2022     76            144           103  Whatsapp
# 35  09/03/2022      1             80            16  Whatsapp
# 36  09/04/2022      6             38            33  Whatsapp
# 37  09/05/2022    126            218           121  Whatsapp
# 38  09/06/2022     91            205           110  Whatsapp
# 39  09/07/2022    160            212            83  Whatsapp
# 40  09/08/2022     69            217            82  Whatsapp
# ...

# %%
#Subsecting rows
df['Usage'] > 50
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16     True
# 17     True
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33    False
# 34     True
# 35    False
# 36    False
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47    False
# 48     True
# 49     True
# 50     True
# 51     True
# 52     True
# 53     True
# Name: Usage, dtype: bool

# %%
#Subsecting rows
df[(df['App'] == 'Whatsapp' )| (df['App'] == 'Instagram')]
# Out:
#           Date  Usage  Notifications  Times opened        App
# 0   08/26/2022     38             70            49  Instagram
# 1   08/27/2022     39             43            48  Instagram
# 2   08/28/2022     64            231            55  Instagram
# 3   08/29/2022     14             35            23  Instagram
# 4   08/30/2022      3             19             5  Instagram
# 5   08/31/2022     19             25            20  Instagram
# 6   09/01/2022     44             23            57  Instagram
# 7   09/02/2022     16             28            22  Instagram
# 8   09/03/2022     27             15            25  Instagram
# 9   09/04/2022     72             29            30  Instagram
# 10  09/05/2022     42             24            51  Instagram
# 11  09/06/2022     19             34            25  Instagram
# 12  09/07/2022     38             23            19  Instagram
# 13  09/08/2022     71             48            43  Instagram
# ...
